# %% [markdown]
# <a href="https://colab.research.google.com/github/mrdbourke/pytorch-deep-learning/blob/main/extras/exercises/06_pytorch_transfer_learning_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# %%html
# <style>
# div {
#     width: 80ch !important; /* or whatever width in whatever CSS units you want */
# }
# </style>

# %% [markdown]
# # 06. PyTorch Transfer Learning Exercises
#
# Welcome to the 06. PyTorch Transfer Learning exercise template notebook.
#
# There are several questions in this notebook and it's your goal to answer them by writing Python and PyTorch code.
#
# > **Note:** There may be more than one solution to each of the exercises, don't worry too much about the *exact* right answer. Try to write some code that works first and then improve it if you can.
#
# ## Resources and solutions
#
# * These exercises/solutions are based on [section 06. PyTorch Transfer Learning](https://www.learnpytorch.io/06_pytorch_transfer_learning/) of the Learn PyTorch for Deep Learning course by Zero to Mastery.
#
# **Solutions:**
#
# Try to complete the code below *before* looking at these.
#
# * See a live [walkthrough of the solutions (errors and all) on YouTube](https://youtu.be/ueLolShyFqs).
# * See an example [solutions notebook for these exercises on GitHub](https://github.com/mrdbourke/pytorch-deep-learning/blob/main/extras/solutions/06_pytorch_transfer_learning_exercise_solutions.ipynb).

# %% [markdown]
# ## 1. Make predictions on the entire test dataset and plot a confusion matrix for the results of our model compared to the truth labels.
# * **Note:** You will need to get the dataset and the trained model/retrain the model from notebook 06 to perform predictions.
# * Check out [03. PyTorch Computer Vision section 10](https://www.learnpytorch.io/03_pytorch_computer_vision/#10-making-a-confusion-matrix-for-further-prediction-evaluation) for ideas.

# %%
# Load libraires. Import required libraries/code
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt

from torch import nn
from torchvision import transforms, datasets

# Try to get torchinfo, install it if it doesn't work
try:
    from torchinfo import summary
except:
    print("[INFO] Couldn't find torchinfo... installing it.")
    # !pip install -q torchinfo
    from torchinfo import summary

# Try to import the going_modular directory, download it from GitHub if it doesn't work
try:
    from going_modular.going_modular import data_setup, engine
except:
    # Get the going_modular scripts
    print("[INFO] Couldn't find going_modular scripts... downloading them from GitHub.")
    # !git clone https://github.com/mrdbourke/pytorch-deep-learning
    # !mv pytorch-deep-learning/going_modular .
    # !rm -rf pytorch-deep-learning
    from going_modular.going_modular import data_setup, engine
# Out:
# [INFO] Couldn't find torchinfo... installing it.
# [INFO] Couldn't find going_modular scripts... downloading them from GitHub.
# Cloning into 'pytorch-deep-learning'...
# remote: Enumerating objects: 4056, done.
# remote: Total 4056 (delta 0), reused 0 (delta 0), pack-reused 4056
# Receiving objects: 100% (4056/4056), 646.90 MiB | 40.58 MiB/s, done.
# Resolving deltas: 100% (2372/2372), done.
# Updating files: 100% (248/248), done.

# %%
# Setup device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# ### Get data

# %%
import os
import requests
import zipfile

from pathlib import Path

# Setup path to data folder
data_path = Path("data/")
image_path = data_path / "pizza_steak_sushi"

# If the image folder doesn't exist, download it and prepare it...
if image_path.is_dir():
    print(f"{image_path} directory exists.")
else:
    print(f"Did not find {image_path} directory, creating one...")
    image_path.mkdir(parents=True, exist_ok=True)

    # Download pizza, steak, sushi data
    with open(data_path / "pizza_steak_sushi.zip", "wb") as f:
        request = requests.get(
            "https://github.com/mrdbourke/pytorch-deep-learning/raw/main/data/pizza_steak_sushi.zip"
        )
        print("Downloading pizza, steak, sushi data...")
        f.write(request.content)

    # Unzip pizza, steak, sushi data
    with zipfile.ZipFile(data_path / "pizza_steak_sushi.zip", "r") as zip_ref:
        print("Unzipping pizza, steak, sushi data...")
        zip_ref.extractall(image_path)

    # Remove .zip file
    os.remove(data_path / "pizza_steak_sushi.zip")

# Setup Dirs
train_dir = image_path / "train"
test_dir = image_path / "test"
# Out:
# Did not find data/pizza_steak_sushi directory, creating one...
# Downloading pizza, steak, sushi data...
# Unzipping pizza, steak, sushi data...

# %% [markdown]
# ### Prepare data

# %%
# Create a transforms pipeline
simple_transform = transforms.Compose(
    [
        transforms.Resize(
            (224, 224)
        ),  # 1. Reshape all images to 224x224 (though some models may require different sizes)
        transforms.ToTensor(),  # 2. Turn image values to between 0 & 1
        transforms.Normalize(
            mean=[
                0.485,
                0.456,
                0.406,
            ],  # 3. A mean of [0.485, 0.456, 0.406] (across each colour channel)
            std=[0.229, 0.224, 0.225],
        ),  # 4. A standard deviation of [0.229, 0.224, 0.225] (across each colour channel),
    ]
)

# %%
# Create training and testing DataLoader's as well as get a list of class names
train_dataloader, test_dataloader, class_names = data_setup.create_dataloaders(
    train_dir=train_dir,
    test_dir=test_dir,
    transform=simple_transform,  # resize, convert images to between 0 & 1 and normalize them
    batch_size=32,
)  # set mini-batch size to 32

train_dataloader, test_dataloader, class_names
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x79d93b287550>,
#  <torch.utils.data.dataloader.DataLoader at 0x79d93b287190>,
#  ['pizza', 'steak', 'sushi'])

# %% [markdown]
# ### Get and prepare a pretrained model

# %%
# Setup the model with pretrained weights and send it to the target device
# model_0 = torchvision.models.efficientnet_b0(pretrained=True).to(device)
weights = (
    torchvision.models.EfficientNet_B0_Weights.DEFAULT
)  # .DEFAULT = best available weights
model_0 = torchvision.models.efficientnet_b0(weights=weights).to(device)
# model_0 # uncomment to output (it's very long)
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 122MB/s]

# %%
# Freeze all base layers in the "features" section of the model (the feature extractor) by setting requires_grad=False
for param in model_0.features.parameters():
    param.requires_grad = False

# %%
# Set the manual seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Get the length of class_names (one output unit for each class)
output_shape = len(class_names)

# Recreate the classifier layer and seed it to the target device
model_0.classifier = torch.nn.Sequential(
    torch.nn.Dropout(p=0.2, inplace=True),
    torch.nn.Linear(
        in_features=1280,
        out_features=output_shape,  # same number of output units as our number of classes
        bias=True,
    ),
).to(device)

# %%
summary(model_0, input_size=(1, 3, 224, 224))
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# EfficientNet                                            [1, 3]                    --
# ├─Sequential: 1-1                                       [1, 1280, 7, 7]           --
# │    └─Conv2dNormActivation: 2-1                        [1, 32, 112, 112]         --
# │    │    └─Conv2d: 3-1                                 [1, 32, 112, 112]         (864)
# │    │    └─BatchNorm2d: 3-2                            [1, 32, 112, 112]         (64)
# │    │    └─SiLU: 3-3                                   [1, 32, 112, 112]         --
# │    └─Sequential: 2-2                                  [1, 16, 112, 112]         --
# │    │    └─MBConv: 3-4                                 [1, 16, 112, 112]         (1,448)
# │    └─Sequential: 2-3                                  [1, 24, 56, 56]           --
# │    │    └─MBConv: 3-5                                 [1, 24, 56, 56]           (6,004)
# │    │    └─MBConv: 3-6                                 [1, 24, 56, 56]           (10,710)
# │    └─Sequential: 2-4                                  [1, 40, 28, 28]           --
# │    │    └─MBConv: 3-7                                 [1, 40, 28, 28]           (15,350)
# │    │    └─MBConv: 3-8                                 [1, 40, 28, 28]           (31,290)
# │    └─Sequential: 2-5                                  [1, 80, 14, 14]           --
# │    │    └─MBConv: 3-9                                 [1, 80, 14, 14]           (37,130)
# │    │    └─MBConv: 3-10                                [1, 80, 14, 14]           (102,900)
# │    │    └─MBConv: 3-11                                [1, 80, 14, 14]           (102,900)
# │    └─Sequential: 2-6                                  [1, 112, 14, 14]          --
# │    │    └─MBConv: 3-12                                [1, 112, 14, 14]          (126,004)
# │    │    └─MBConv: 3-13                                [1, 112, 14, 14]          (208,572)
# │    │    └─MBConv: 3-14                                [1, 112, 14, 14]          (208,572)
# │    └─Sequential: 2-7                                  [1, 192, 7, 7]            --
# │    │    └─MBConv: 3-15                                [1, 192, 7, 7]            (262,492)
# │    │    └─MBConv: 3-16                                [1, 192, 7, 7]            (587,952)
# │    │    └─MBConv: 3-17                                [1, 192, 7, 7]            (587,952)
# │    │    └─MBConv: 3-18                                [1, 192, 7, 7]            (587,952)
# │    └─Sequential: 2-8                                  [1, 320, 7, 7]            --
# │    │    └─MBConv: 3-19                                [1, 320, 7, 7]            (717,232)
# │    └─Conv2dNormActivation: 2-9                        [1, 1280, 7, 7]           --
# │    │    └─Conv2d: 3-20                                [1, 1280, 7, 7]           (409,600)
# │    │    └─BatchNorm2d: 3-21                           [1, 1280, 7, 7]           (2,560)
# │    │    └─SiLU: 3-22                                  [1, 1280, 7, 7]           --
# ├─AdaptiveAvgPool2d: 1-2                                [1, 1280, 1, 1]           --
# ├─Sequential: 1-3                                       [1, 3]                    --
# │    └─Dropout: 2-10                                    [1, 1280]                 --
# │    └─Linear: 2-11                                     [1, 3]                    3,843
# =========================================================================================================
# Total params: 4,011,391
# Trainable params: 3,843
# Non-trainable params: 4,007,548
# Total mult-adds (M): 384.59
# =========================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 107.88
# Params size (MB): 16.05
# Estimated Total Size (MB): 124.53
# =========================================================================================================

# %% [markdown]
# ### Train model

# %%
# Define loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_0.parameters(), lr=0.001)

# %%
# Set the random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Start the timer
from timeit import default_timer as timer

start_time = timer()

# Setup training and save the results
model_0_results = engine.train(
    model=model_0,
    train_dataloader=train_dataloader,
    test_dataloader=test_dataloader,
    optimizer=optimizer,
    loss_fn=loss_fn,
    epochs=5,
    device=device,
)

# End the timer and print out how long it took
end_time = timer()
print(f"[INFO] Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Epoch: 1 | train_loss: 1.0895 | train_acc: 0.4414 | test_loss: 0.9202 | test_acc: 0.5085
# Epoch: 2 | train_loss: 0.8682 | train_acc: 0.7734 | test_loss: 0.8022 | test_acc: 0.7434
# Epoch: 3 | train_loss: 0.7771 | train_acc: 0.7812 | test_loss: 0.7399 | test_acc: 0.7737
# Epoch: 4 | train_loss: 0.7249 | train_acc: 0.7422 | test_loss: 0.6472 | test_acc: 0.8864
# Epoch: 5 | train_loss: 0.6445 | train_acc: 0.7812 | test_loss: 0.6244 | test_acc: 0.8968
# [INFO] Total training time: 14.628 seconds

# %%
import matplotlib.pyplot as plt


def plot_results(results, title=None):
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.plot(results["train_loss"], label="train")
    plt.plot(results["test_loss"], label="test")
    plt.title("Loss")
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(results["train_acc"], label="train")
    plt.plot(results["test_acc"], label="test")
    plt.title("Acciracy")
    plt.legend()


plot_results(results=model_0_results)

# %% [markdown]
# ### Make predictions on the entire test dataset with the model

# %%
# TODO
def get_test_predictions(model, device):
    model.to(device)
    model.eval()

    y_pred = []
    y_prob = []

    with torch.inference_mode():
        for X, y in test_dataloader:
            X, y = X.to(device), y.to(device)
            pred_logit = model(X)

            y_prob_batch = torch.softmax(pred_logit, dim=1)
            y_pred_batch = y_prob_batch.argmax(dim=1)

            y_pred.append(y_pred_batch.cpu())
            y_prob.append(y_prob_batch.cpu())

    return torch.cat(y_pred), torch.cat(y_prob)


test_pred, test_prob = get_test_predictions(model=model_0, device=device)

# %% [markdown]
# ### Make a confusion matrix with the test preds and the truth labels

# %% [markdown]
# Need the following libraries to make a confusion matrix:
# * torchmetrics - https://torchmetrics.readthedocs.io/en/stable/
# * mlxtend - http://rasbt.github.io/mlxtend/

# %%
# See if torchmetrics exists, if not, install it
try:
    import torchmetrics, mlxtend
    print(f"mlxtend version: {mlxtend.__version__}")
    assert int(mlxtend.__version__.split(".")[1]) >= 19, "mlxtend verison should be 0.19.0 or higher"
except:
    # !pip install -q torchmetrics -U mlxtend # <- Note: If you're using Google Colab, this may require restarting the runtime
    import torchmetrics, mlxtend
    print(f"mlxtend version: {mlxtend.__version__}")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.5/841.5 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 8.5 MB/s eta 0:00:00
# mlxtend version: 0.23.1

# %%
# Import mlxtend upgraded version
import mlxtend

print(mlxtend.__version__)
assert (
    int(mlxtend.__version__.split(".")[1]) >= 19
)  # should be version 0.19.0 or higher
# Out:
# 0.23.1

# %%
type(test_dataloader.dataset.targets)
# Out:
# list

# %%
# DONE

from torchmetrics import ConfusionMatrix
from mlxtend.plotting import plot_confusion_matrix

# 2. Setup confusion matrix instance and compare predictions to targets
test_target = torch.Tensor(test_dataloader.dataset.targets)
confmat = ConfusionMatrix(num_classes=len(class_names), task="multiclass")
confmat_tensor = confmat(preds=test_pred, target=test_target)


# 3. Plot the confusion matrix
fig, ax = plot_confusion_matrix(
    conf_mat=confmat_tensor.numpy(),  # matplotlib likes working with NumPy
    class_names=class_names,  # turn the row and column labels into class names
    figsize=(10, 7),
)

# %% [markdown]
# ## 2. Get the "most wrong" of the predictions on the test dataset and plot the 5 "most wrong" images. You can do this by:
# * Predicting across all of the test dataset, storing the labels and predicted probabilities.
# * Sort the predictions by *wrong prediction* and then *descending predicted probabilities*, this will give you the wrong predictions with the *highest* prediction probabilities, in other words, the "most wrong".
# * Plot the top 5 "most wrong" images, why do you think the model got these wrong?
#
# You'll want to:
# * Create a DataFrame with sample, label, prediction, pred prob
# * Sort DataFrame by correct (does label == prediction)
# * Sort DataFrame by pred prob (descending)
# * Plot the top 5 "most wrong" image predictions

# %%
# DONE

import pandas as pd

samples_data = test_dataloader.dataset.samples
samples = [item[0] for item in samples_data]
test_probs = [float(i[i.argmax()]) for i in test_prob]

df_pred = pd.DataFrame(
    {
        "sample": samples,
        "predictions": test_pred,
        "targets": test_target,
        "probability": test_probs,
    }
)
df_pred = df_pred.astype({"targets": "int16"})
df_pred["correct"] = df_pred["predictions"] == df_pred["targets"]
df_pred = df_pred.sort_values(["correct", "probability"], ascending=[True, True])


df_top5 = df_pred[:5]
p = df_top5["sample"].iloc[0]
df_top5

# In the solution creates list where save dict for each item.

# Create a function to return a list of dictionaries with sample, label, prediction, pred prob
# def pred_and_store(test_paths, model, transform, class_names, device):
#   test_pred_list = []
#   for path in tqdm(test_paths):
#     # Create empty dict to store info for each sample
#     pred_dict = {}

#     # Get sample path
#     pred_dict["image_path"] = path

#     # Get class name
#     class_name = path.parent.stem
#     pred_dict["class_name"] = class_name

#     # Get prediction and prediction probability
#     from PIL import Image
#     img = Image.open(path) # open image
#     transformed_image = transform(img).unsqueeze(0) # transform image and add batch dimension
#     model.eval()
#     with torch.inference_mode():
#       pred_logit = model(transformed_image.to(device))
#       pred_prob = torch.softmax(pred_logit, dim=1)
#       pred_label = torch.argmax(pred_prob, dim=1)
#       pred_class = class_names[pred_label.cpu()]

#       # Make sure things in the dictionary are back on the CPU
#       pred_dict["pred_prob"] = pred_prob.unsqueeze(0).max().cpu().item()
#       pred_dict["pred_class"] = pred_class

#     # Does the pred match the true label?
#     pred_dict["correct"] = class_name == pred_class

#     # print(pred_dict)
#     # Add the dictionary to the list of preds
#     test_pred_list.append(pred_dict)

#   return test_pred_list
# Out:
#                                            sample  predictions  targets  \
# 10  data/pizza_steak_sushi/test/pizza/2218680.jpg            1        0
# 55  data/pizza_steak_sushi/test/sushi/2276986.jpg            1        2
# 13  data/pizza_steak_sushi/test/pizza/2871261.jpg            1        0
# 15   data/pizza_steak_sushi/test/pizza/309892.jpg            2        0
# 12  data/pizza_steak_sushi/test/pizza/2508636.jpg            2        0
#
#     probability  correct
# 10     0.384089    False
# 55     0.403894    False
# 13     0.425909    False
# 15     0.426874    False
# 12     0.435139    False

# %%
from PIL import Image

plt.figure(figsize=(15, 10))
# plt.suptitle('Most wrong')

for i, idx in enumerate(df_top5.index):
    path = df_top5["sample"].loc[idx]
    img = Image.open(path)
    img_ar = np.asanyarray(img)
    plt.subplot(1, 5, i + 1)
    plt.axis(False)
    cnmuber = test_dataloader.dataset[idx][1]
    cnmuber_pred = df_top5["predictions"].loc[idx]
    plt.imshow(img)
    plt.title(
        "predicted - "
        + class_names[cnmuber_pred]
        + "\n"
        + "original -  "
        + class_names[cnmuber]
    )

# %% [markdown]
# ## 3. Predict on your own image of pizza/steak/sushi - how does the model go? What happens if you predict on an image that isn't pizza/steak/sushi?
# * Here you can get an image from a website like http://www.unsplash.com to try it out or you can upload your own.

# %%
# DONE: Get an image of pizza/steak/sushi
from pathlib import Path
import requests
import zipfile
import os


def pred_and_plot_img(model, img_path):

    model.eval()

    model.to(device)

    with torch.inference_mode():
        img = Image.open(img_path)

        img_tr = simple_transform(img).unsqueeze(dim=0)
        logit_pred = model(img_tr.to(device))
        prob_pred = logit_pred.softmax(dim=1)
        target_pred = prob_pred.argmax(dim=1)

        plt.figure()
        plt.imshow(img)
        plt.title(f"class: {class_names[target_pred]}, prob: {prob_pred.max():.3f}")
        plt.axis(False)


# Setup path to data folder
my_data_path = Path("my_data")
my_image_path = my_data_path / "images"

# If the image folder doesn't exist, download it and prepare it...
if my_image_path.is_dir():
    print(f"{my_image_path} directory exists.")
else:
    print(f"Did not find {my_image_path} directory, creating one...")
    my_image_path.mkdir(parents=True, exist_ok=True)

    # Download pizza, steak, sushi data
    with open(my_data_path / "images.zip", "wb") as f:
        request = requests.get(
            "https://github.com/AntonTroitskii/pytorch-deep-learning/raw/course/my_data/images.zip"
        )
        print("Downloading my data...")
        f.write(request.content)

    # Unzip pizza, steak, sushi data
    with zipfile.ZipFile(my_data_path / "images.zip", "r") as zip_ref:
        print("Unzipping pizza, steak, sushi data...")
        zip_ref.extractall(my_data_path)

    # Remove .zip file
    os.remove(my_data_path / "images.zip")

# https://github.com/AntonTroitskii/pytorch-deep-learning/blob/course/my_data/images.zip
my_data_path = Path("my_data/images")
img_path_list = []
img_path_list.append(my_data_path / "pizza.png")
img_path_list.append(my_data_path / "stake.png")
img_path_list.append(my_data_path / "sushi.png")

pred_and_plot_img(model_0, img_path_list[1])
# Out:
# my_data/images directory exists.

# %%
# DONE: Get an image of not pizza/steak/sushi
img_path = my_data_path / "pelmeni.png"

pred_and_plot_img(model_0, img_path)

# %% [markdown]
# ## 4. Train the model from section 4  in notebook 06 part 3 for longer (10 epochs should do), what happens to the performance?
#
# * See the model in notebook 06 part 3 for reference: https://www.learnpytorch.io/06_pytorch_transfer_learning/#3-getting-a-pretrained-model

# %%
# TODO: Recreate a new model
weights = torchvision.models.EfficientNet_B0_Weights.DEFAULT
model_1 = torchvision.models.efficientnet_b0(weights=weights).to(device)


# Set the manual seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Get the length of class_names (one output unit for each class)
output_shape = len(class_names)

# Recreate the classifier layer and seed it to the target device
model_1.classifier = torch.nn.Sequential(
    torch.nn.Dropout(p=0.2, inplace=True),
    torch.nn.Linear(
        in_features=1280,
        out_features=output_shape,  # same number of output units as our number of classes
        bias=True,
    ),
).to(device)


summary(
    model_1,
    # make sure this is "input_size", not "input_shape" (batch_size, color_channels, height, width)
    input_size=(32, 3, 224, 224),
    verbose=0,
    col_names=["input_size", "output_size", "num_params", "trainable"],
    col_width=20,
    row_settings=["var_names"],
)
# Out:
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# EfficientNet (EfficientNet)                                  [32, 3, 224, 224]    [32, 3]              --                   True
# ├─Sequential (features)                                      [32, 3, 224, 224]    [32, 1280, 7, 7]     --                   True
# │    └─Conv2dNormActivation (0)                              [32, 3, 224, 224]    [32, 32, 112, 112]   --                   True
# │    │    └─Conv2d (0)                                       [32, 3, 224, 224]    [32, 32, 112, 112]   864                  True
# │    │    └─BatchNorm2d (1)                                  [32, 32, 112, 112]   [32, 32, 112, 112]   64                   True
# │    │    └─SiLU (2)                                         [32, 32, 112, 112]   [32, 32, 112, 112]   --                   --
# │    └─Sequential (1)                                        [32, 32, 112, 112]   [32, 16, 112, 112]   --                   True
# │    │    └─MBConv (0)                                       [32, 32, 112, 112]   [32, 16, 112, 112]   1,448                True
# │    └─Sequential (2)                                        [32, 16, 112, 112]   [32, 24, 56, 56]     --                   True
# │    │    └─MBConv (0)                                       [32, 16, 112, 112]   [32, 24, 56, 56]     6,004                True
# │    │    └─MBConv (1)                                       [32, 24, 56, 56]     [32, 24, 56, 56]     10,710               True
# │    └─Sequential (3)                                        [32, 24, 56, 56]     [32, 40, 28, 28]     --                   True
# │    │    └─MBConv (0)                                       [32, 24, 56, 56]     [32, 40, 28, 28]     15,350               True
# │    │    └─MBConv (1)                                       [32, 40, 28, 28]     [32, 40, 28, 28]     31,290               True
# │    └─Sequential (4)                                        [32, 40, 28, 28]     [32, 80, 14, 14]     --                   True
# │    │    └─MBConv (0)                                       [32, 40, 28, 28]     [32, 80, 14, 14]     37,130               True
# │    │    └─MBConv (1)                                       [32, 80, 14, 14]     [32, 80, 14, 14]     102,900              True
# │    │    └─MBConv (2)                                       [32, 80, 14, 14]     [32, 80, 14, 14]     102,900              True
# │    └─Sequential (5)                                        [32, 80, 14, 14]     [32, 112, 14, 14]    --                   True
# │    │    └─MBConv (0)                                       [32, 80, 14, 14]     [32, 112, 14, 14]    126,004              True
# │    │    └─MBConv (1)                                       [32, 112, 14, 14]    [32, 112, 14, 14]    208,572              True
# │    │    └─MBConv (2)                                       [32, 112, 14, 14]    [32, 112, 14, 14]    208,572              True
# │    └─Sequential (6)                                        [32, 112, 14, 14]    [32, 192, 7, 7]      --                   True
# │    │    └─MBConv (0)                                       [32, 112, 14, 14]    [32, 192, 7, 7]      262,492              True
# │    │    └─MBConv (1)                                       [32, 192, 7, 7]      [32, 192, 7, 7]      587,952              True
# │    │    └─MBConv (2)                                       [32, 192, 7, 7]      [32, 192, 7, 7]      587,952              True
# │    │    └─MBConv (3)                                       [32, 192, 7, 7]      [32, 192, 7, 7]      587,952              True
# │    └─Sequential (7)                                        [32, 192, 7, 7]      [32, 320, 7, 7]      --                   True
# │    │    └─MBConv (0)                                       [32, 192, 7, 7]      [32, 320, 7, 7]      717,232              True
# │    └─Conv2dNormActivation (8)                              [32, 320, 7, 7]      [32, 1280, 7, 7]     --                   True
# │    │    └─Conv2d (0)                                       [32, 320, 7, 7]      [32, 1280, 7, 7]     409,600              True
# │    │    └─BatchNorm2d (1)                                  [32, 1280, 7, 7]     [32, 1280, 7, 7]     2,560                True
# │    │    └─SiLU (2)                                         [32, 1280, 7, 7]     [32, 1280, 7, 7]     --                   --
# ├─AdaptiveAvgPool2d (avgpool)                                [32, 1280, 7, 7]     [32, 1280, 1, 1]     --                   --
# ├─Sequential (classifier)                                    [32, 1280]           [32, 3]              --                   True
# │    └─Dropout (0)                                           [32, 1280]           [32, 1280]           --                   --
# │    └─Linear (1)                                            [32, 1280]           [32, 3]              3,843                True
# ============================================================================================================================================
# Total params: 4,011,391
# Trainable params: 4,011,391
# Non-trainable params: 0
# Total mult-adds (G): 12.31
# ============================================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 3452.09
# Params size (MB): 16.05
# Estimated Total Size (MB): 3487.41
# ============================================================================================================================================

# %%
# TODO: Train the model for 10 epochs


# Set the random seeds
from timeit import default_timer as timer

torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Start the timer

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_1.parameters(), lr=0.001)


start_time = timer()
# Setup training and save the results
model_1_results = engine.train(
    model=model_1,
    train_dataloader=train_dataloader,
    test_dataloader=test_dataloader,
    optimizer=optimizer,
    loss_fn=loss_fn,
    epochs=10,
    device=device,
)

# End the timer and print out how long it took
end_time = timer()
print(f"[INFO] Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Epoch: 1 | train_loss: 0.7723 | train_acc: 0.6406 | test_loss: 0.3826 | test_acc: 0.8561
# Epoch: 2 | train_loss: 0.1387 | train_acc: 0.9961 | test_loss: 0.2661 | test_acc: 0.9280
# Epoch: 3 | train_loss: 0.0876 | train_acc: 0.9883 | test_loss: 0.1888 | test_acc: 0.9280
# Epoch: 4 | train_loss: 0.3477 | train_acc: 0.8594 | test_loss: 0.2645 | test_acc: 0.9176
# Epoch: 5 | train_loss: 0.1824 | train_acc: 0.8555 | test_loss: 0.3032 | test_acc: 0.8759
# Epoch: 6 | train_loss: 0.1675 | train_acc: 0.8633 | test_loss: 0.2536 | test_acc: 0.9176
# Epoch: 7 | train_loss: 0.0852 | train_acc: 0.9922 | test_loss: 0.2158 | test_acc: 0.9583
# Epoch: 8 | train_loss: 0.2504 | train_acc: 0.8750 | test_loss: 0.2155 | test_acc: 0.9583
# Epoch: 9 | train_loss: 0.3774 | train_acc: 0.8477 | test_loss: 0.3154 | test_acc: 0.9176
# Epoch: 10 | train_loss: 0.1997 | train_acc: 0.9609 | test_loss: 0.2488 | test_acc: 0.9167
# [INFO] Total training time: 22.802 seconds

# %%
plot_results(results=model_1_results)

# %% [markdown]
# ## 5. Train the model from section 4 above with more data, say 20% of the images from Food101 of Pizza, Steak and Sushi images.
# * You can find the [20% Pizza, Steak, Sushi dataset](https://github.com/mrdbourke/pytorch-deep-learning/blob/main/data/pizza_steak_sushi_20_percent.zip) on the course GitHub. It was created with the notebook [`extras/04_custom_data_creation.ipynb`](https://github.com/mrdbourke/pytorch-deep-learning/blob/main/extras/04_custom_data_creation.ipynb).

# %% [markdown]
# ### Get 20% data

# %%
import os
import requests
import zipfile

from pathlib import Path

# Setup path to data folder
data_path = Path("data/")
image_path = data_path / "pizza_steak_sushi_20_percent"
image_data_zip_path = "pizza_steak_sushi_20_percent.zip"

# If the image folder doesn't exist, download it and prepare it...
if image_path.is_dir():
    print(f"{image_path} directory exists.")
else:
    print(f"Did not find {image_path} directory, creating one...")
    image_path.mkdir(parents=True, exist_ok=True)

    # Download pizza, steak, sushi data
    with open(data_path / image_data_zip_path, "wb") as f:
        request = requests.get(
            "https://github.com/mrdbourke/pytorch-deep-learning/raw/main/data/pizza_steak_sushi_20_percent.zip"
        )
        print("Downloading pizza, steak, sushi data...")
        f.write(request.content)

    # Unzip pizza, steak, sushi data
    with zipfile.ZipFile(data_path / image_data_zip_path, "r") as zip_ref:
        print("Unzipping pizza, steak, sushi 20% data...")
        zip_ref.extractall(image_path)

    # Remove .zip file
    os.remove(data_path / image_data_zip_path)

# Setup Dirs
train_dir_20_percent = image_path / "train"
test_dir_20_percent = image_path / "test"

train_dir_20_percent, test_dir_20_percent
# Out:
# Did not find data/pizza_steak_sushi_20_percent directory, creating one...
# Downloading pizza, steak, sushi data...
# Unzipping pizza, steak, sushi 20% data...
# (PosixPath('data/pizza_steak_sushi_20_percent/train'),
#  PosixPath('data/pizza_steak_sushi_20_percent/test'))

# %% [markdown]
# ### Create DataLoaders

# %%
# Create a transforms pipeline
simple_transform = transforms.Compose(
    [
        transforms.Resize(
            (224, 224)
        ),  # 1. Reshape all images to 224x224 (though some models may require different sizes)
        transforms.ToTensor(),  # 2. Turn image values to between 0 & 1
        transforms.Normalize(
            mean=[
                0.485,
                0.456,
                0.406,
            ],  # 3. A mean of [0.485, 0.456, 0.406] (across each colour channel)
            std=[0.229, 0.224, 0.225],
        ),  # 4. A standard deviation of [0.229, 0.224, 0.225] (across each colour channel),
    ]
)

# %%
# Create training and testing DataLoader's as well as get a list of class names
train_dataloader_20_percent, test_dataloader_20_percent, class_names = (
    data_setup.create_dataloaders(
        train_dir=train_dir_20_percent,
        test_dir=test_dir_20_percent,
        transform=simple_transform,  # resize, convert images to between 0 & 1 and normalize them
        batch_size=32,
    )
)  # set mini-batch size to 32

train_dataloader_20_percent, test_dataloader_20_percent, class_names
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x79d893dbba60>,
#  <torch.utils.data.dataloader.DataLoader at 0x79d893dbbe20>,
#  ['pizza', 'steak', 'sushi'])

# %% [markdown]
# ### Get a pretrained model

# %%
# TODO

weights = torchvision.models.EfficientNet_B0_Weights.DEFAULT
model_2 = torchvision.models.efficientnet_b0(weights=weights).to(device)

# Set the manual seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)


# Get the length of class_names (one output unit for each class)
output_shape = len(class_names)

# Recreate the classifier layer and seed it to the target device
model_2.classifier = torch.nn.Sequential(
    torch.nn.Dropout(p=0.2, inplace=True),
    torch.nn.Linear(
        in_features=1280,
        out_features=output_shape,  # same number of output units as our number of classes
        bias=True,
    ),
).to(device)


summary(
    model_2,
    input_size=(
        32,
        3,
        224,
        224,
    ),  # make sure this is "input_size", not "input_shape" (batch_size, color_channels, height, width)
    verbose=0,
    col_names=["input_size", "output_size", "num_params", "trainable"],
    col_width=20,
    row_settings=["var_names"],
)
# Out:
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# EfficientNet (EfficientNet)                                  [32, 3, 224, 224]    [32, 3]              --                   True
# ├─Sequential (features)                                      [32, 3, 224, 224]    [32, 1280, 7, 7]     --                   True
# │    └─Conv2dNormActivation (0)                              [32, 3, 224, 224]    [32, 32, 112, 112]   --                   True
# │    │    └─Conv2d (0)                                       [32, 3, 224, 224]    [32, 32, 112, 112]   864                  True
# │    │    └─BatchNorm2d (1)                                  [32, 32, 112, 112]   [32, 32, 112, 112]   64                   True
# │    │    └─SiLU (2)                                         [32, 32, 112, 112]   [32, 32, 112, 112]   --                   --
# │    └─Sequential (1)                                        [32, 32, 112, 112]   [32, 16, 112, 112]   --                   True
# │    │    └─MBConv (0)                                       [32, 32, 112, 112]   [32, 16, 112, 112]   1,448                True
# │    └─Sequential (2)                                        [32, 16, 112, 112]   [32, 24, 56, 56]     --                   True
# │    │    └─MBConv (0)                                       [32, 16, 112, 112]   [32, 24, 56, 56]     6,004                True
# │    │    └─MBConv (1)                                       [32, 24, 56, 56]     [32, 24, 56, 56]     10,710               True
# │    └─Sequential (3)                                        [32, 24, 56, 56]     [32, 40, 28, 28]     --                   True
# │    │    └─MBConv (0)                                       [32, 24, 56, 56]     [32, 40, 28, 28]     15,350               True
# │    │    └─MBConv (1)                                       [32, 40, 28, 28]     [32, 40, 28, 28]     31,290               True
# │    └─Sequential (4)                                        [32, 40, 28, 28]     [32, 80, 14, 14]     --                   True
# │    │    └─MBConv (0)                                       [32, 40, 28, 28]     [32, 80, 14, 14]     37,130               True
# │    │    └─MBConv (1)                                       [32, 80, 14, 14]     [32, 80, 14, 14]     102,900              True
# │    │    └─MBConv (2)                                       [32, 80, 14, 14]     [32, 80, 14, 14]     102,900              True
# │    └─Sequential (5)                                        [32, 80, 14, 14]     [32, 112, 14, 14]    --                   True
# │    │    └─MBConv (0)                                       [32, 80, 14, 14]     [32, 112, 14, 14]    126,004              True
# │    │    └─MBConv (1)                                       [32, 112, 14, 14]    [32, 112, 14, 14]    208,572              True
# │    │    └─MBConv (2)                                       [32, 112, 14, 14]    [32, 112, 14, 14]    208,572              True
# │    └─Sequential (6)                                        [32, 112, 14, 14]    [32, 192, 7, 7]      --                   True
# │    │    └─MBConv (0)                                       [32, 112, 14, 14]    [32, 192, 7, 7]      262,492              True
# │    │    └─MBConv (1)                                       [32, 192, 7, 7]      [32, 192, 7, 7]      587,952              True
# │    │    └─MBConv (2)                                       [32, 192, 7, 7]      [32, 192, 7, 7]      587,952              True
# │    │    └─MBConv (3)                                       [32, 192, 7, 7]      [32, 192, 7, 7]      587,952              True
# │    └─Sequential (7)                                        [32, 192, 7, 7]      [32, 320, 7, 7]      --                   True
# │    │    └─MBConv (0)                                       [32, 192, 7, 7]      [32, 320, 7, 7]      717,232              True
# │    └─Conv2dNormActivation (8)                              [32, 320, 7, 7]      [32, 1280, 7, 7]     --                   True
# │    │    └─Conv2d (0)                                       [32, 320, 7, 7]      [32, 1280, 7, 7]     409,600              True
# │    │    └─BatchNorm2d (1)                                  [32, 1280, 7, 7]     [32, 1280, 7, 7]     2,560                True
# │    │    └─SiLU (2)                                         [32, 1280, 7, 7]     [32, 1280, 7, 7]     --                   --
# ├─AdaptiveAvgPool2d (avgpool)                                [32, 1280, 7, 7]     [32, 1280, 1, 1]     --                   --
# ├─Sequential (classifier)                                    [32, 1280]           [32, 3]              --                   True
# │    └─Dropout (0)                                           [32, 1280]           [32, 1280]           --                   --
# │    └─Linear (1)                                            [32, 1280]           [32, 3]              3,843                True
# ============================================================================================================================================
# Total params: 4,011,391
# Trainable params: 4,011,391
# Non-trainable params: 0
# Total mult-adds (G): 12.31
# ============================================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 3452.09
# Params size (MB): 16.05
# Estimated Total Size (MB): 3487.41
# ============================================================================================================================================

# %% [markdown]
# Try to test changing learning rate

# %% [markdown]
# ### Train a model with 20% of the data

# %%
# TODO

# Set the random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Start the timer
from timeit import default_timer as timer

start_time = timer()

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_2.parameters(), lr=0.001)

# Setup training and save the results
model_2_results = engine.train(
    model=model_2,
    train_dataloader=train_dataloader_20_percent,
    test_dataloader=test_dataloader_20_percent,
    optimizer=optimizer,
    loss_fn=loss_fn,
    epochs=10,
    device=device,
)

# End the timer and print out how long it took
end_time = timer()
print(f"[INFO] Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 0.4972 | train_acc: 0.8333 | test_loss: 0.2117 | test_acc: 0.9381
# Epoch: 2 | train_loss: 0.2845 | train_acc: 0.9271 | test_loss: 0.2295 | test_acc: 0.9125
# Epoch: 3 | train_loss: 0.1822 | train_acc: 0.9500 | test_loss: 0.1534 | test_acc: 0.9409
# Epoch: 4 | train_loss: 0.1538 | train_acc: 0.9354 | test_loss: 0.1904 | test_acc: 0.9290
# Epoch: 5 | train_loss: 0.1424 | train_acc: 0.9563 | test_loss: 0.4843 | test_acc: 0.8801
# Epoch: 6 | train_loss: 0.4069 | train_acc: 0.9125 | test_loss: 0.2457 | test_acc: 0.9034
# Epoch: 7 | train_loss: 0.2446 | train_acc: 0.9250 | test_loss: 0.2165 | test_acc: 0.9375
# Epoch: 8 | train_loss: 0.2918 | train_acc: 0.8938 | test_loss: 0.2123 | test_acc: 0.9597
# Epoch: 9 | train_loss: 0.1572 | train_acc: 0.9625 | test_loss: 0.1803 | test_acc: 0.9443
# Epoch: 10 | train_loss: 0.2253 | train_acc: 0.9563 | test_loss: 0.2968 | test_acc: 0.9261
# [INFO] Total training time: 41.510 seconds

# %%
plot_results(results=model_2_results)

# %% [markdown]
# Try to test changing learning rate

# %%
# TODO

weights = torchvision.models.EfficientNet_B0_Weights.DEFAULT
model_21 = torchvision.models.efficientnet_b0(weights=weights).to(device)

# Set the manual seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Get the length of class_names (one output unit for each class)
output_shape = len(class_names)

# Recreate the classifier layer and seed it to the target device
model_21.classifier = torch.nn.Sequential(
    torch.nn.Dropout(p=0.2, inplace=True),
    torch.nn.Linear(
        in_features=1280,
        out_features=output_shape,  # same number of output units as our number of classes
        bias=True,
    ),
).to(device)


summary(
    model_21,
    input_size=(
        32,
        3,
        224,
        224,
    ),  # make sure this is "input_size", not "input_shape" (batch_size, color_channels, height, width)
    verbose=0,
    col_names=["input_size", "output_size", "num_params", "trainable"],
    col_width=20,
    row_settings=["var_names"],
)
# Out:
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# EfficientNet (EfficientNet)                                  [32, 3, 224, 224]    [32, 3]              --                   True
# ├─Sequential (features)                                      [32, 3, 224, 224]    [32, 1280, 7, 7]     --                   True
# │    └─Conv2dNormActivation (0)                              [32, 3, 224, 224]    [32, 32, 112, 112]   --                   True
# │    │    └─Conv2d (0)                                       [32, 3, 224, 224]    [32, 32, 112, 112]   864                  True
# │    │    └─BatchNorm2d (1)                                  [32, 32, 112, 112]   [32, 32, 112, 112]   64                   True
# │    │    └─SiLU (2)                                         [32, 32, 112, 112]   [32, 32, 112, 112]   --                   --
# │    └─Sequential (1)                                        [32, 32, 112, 112]   [32, 16, 112, 112]   --                   True
# │    │    └─MBConv (0)                                       [32, 32, 112, 112]   [32, 16, 112, 112]   1,448                True
# │    └─Sequential (2)                                        [32, 16, 112, 112]   [32, 24, 56, 56]     --                   True
# │    │    └─MBConv (0)                                       [32, 16, 112, 112]   [32, 24, 56, 56]     6,004                True
# │    │    └─MBConv (1)                                       [32, 24, 56, 56]     [32, 24, 56, 56]     10,710               True
# │    └─Sequential (3)                                        [32, 24, 56, 56]     [32, 40, 28, 28]     --                   True
# │    │    └─MBConv (0)                                       [32, 24, 56, 56]     [32, 40, 28, 28]     15,350               True
# │    │    └─MBConv (1)                                       [32, 40, 28, 28]     [32, 40, 28, 28]     31,290               True
# │    └─Sequential (4)                                        [32, 40, 28, 28]     [32, 80, 14, 14]     --                   True
# │    │    └─MBConv (0)                                       [32, 40, 28, 28]     [32, 80, 14, 14]     37,130               True
# │    │    └─MBConv (1)                                       [32, 80, 14, 14]     [32, 80, 14, 14]     102,900              True
# │    │    └─MBConv (2)                                       [32, 80, 14, 14]     [32, 80, 14, 14]     102,900              True
# │    └─Sequential (5)                                        [32, 80, 14, 14]     [32, 112, 14, 14]    --                   True
# │    │    └─MBConv (0)                                       [32, 80, 14, 14]     [32, 112, 14, 14]    126,004              True
# │    │    └─MBConv (1)                                       [32, 112, 14, 14]    [32, 112, 14, 14]    208,572              True
# │    │    └─MBConv (2)                                       [32, 112, 14, 14]    [32, 112, 14, 14]    208,572              True
# │    └─Sequential (6)                                        [32, 112, 14, 14]    [32, 192, 7, 7]      --                   True
# │    │    └─MBConv (0)                                       [32, 112, 14, 14]    [32, 192, 7, 7]      262,492              True
# │    │    └─MBConv (1)                                       [32, 192, 7, 7]      [32, 192, 7, 7]      587,952              True
# │    │    └─MBConv (2)                                       [32, 192, 7, 7]      [32, 192, 7, 7]      587,952              True
# │    │    └─MBConv (3)                                       [32, 192, 7, 7]      [32, 192, 7, 7]      587,952              True
# │    └─Sequential (7)                                        [32, 192, 7, 7]      [32, 320, 7, 7]      --                   True
# │    │    └─MBConv (0)                                       [32, 192, 7, 7]      [32, 320, 7, 7]      717,232              True
# │    └─Conv2dNormActivation (8)                              [32, 320, 7, 7]      [32, 1280, 7, 7]     --                   True
# │    │    └─Conv2d (0)                                       [32, 320, 7, 7]      [32, 1280, 7, 7]     409,600              True
# │    │    └─BatchNorm2d (1)                                  [32, 1280, 7, 7]     [32, 1280, 7, 7]     2,560                True
# │    │    └─SiLU (2)                                         [32, 1280, 7, 7]     [32, 1280, 7, 7]     --                   --
# ├─AdaptiveAvgPool2d (avgpool)                                [32, 1280, 7, 7]     [32, 1280, 1, 1]     --                   --
# ├─Sequential (classifier)                                    [32, 1280]           [32, 3]              --                   True
# │    └─Dropout (0)                                           [32, 1280]           [32, 1280]           --                   --
# │    └─Linear (1)                                            [32, 1280]           [32, 3]              3,843                True
# ============================================================================================================================================
# Total params: 4,011,391
# Trainable params: 4,011,391
# Non-trainable params: 0
# Total mult-adds (G): 12.31
# ============================================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 3452.09
# Params size (MB): 16.05
# Estimated Total Size (MB): 3487.41
# ============================================================================================================================================

# %%
# TODO

# Set the random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Start the timer
from timeit import default_timer as timer

start_time = timer()

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_21.parameters(), lr=0.0001)

# Setup training and save the results
model_2_results = engine.train(
    model=model_21,
    train_dataloader=train_dataloader_20_percent,
    test_dataloader=test_dataloader_20_percent,
    optimizer=optimizer,
    loss_fn=loss_fn,
    epochs=10,
    device=device,
)

# End the timer and print out how long it took
end_time = timer()
print(f"[INFO] Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 0.9979 | train_acc: 0.5542 | test_loss: 0.7076 | test_acc: 0.8795
# Epoch: 2 | train_loss: 0.6732 | train_acc: 0.8729 | test_loss: 0.4511 | test_acc: 0.9227
# Epoch: 3 | train_loss: 0.4550 | train_acc: 0.8833 | test_loss: 0.2759 | test_acc: 0.9568
# Epoch: 4 | train_loss: 0.2536 | train_acc: 0.9563 | test_loss: 0.1877 | test_acc: 0.9812
# Epoch: 5 | train_loss: 0.1991 | train_acc: 0.9667 | test_loss: 0.1414 | test_acc: 0.9784
# Epoch: 6 | train_loss: 0.2204 | train_acc: 0.9208 | test_loss: 0.1256 | test_acc: 0.9631
# Epoch: 7 | train_loss: 0.1795 | train_acc: 0.9271 | test_loss: 0.1124 | test_acc: 0.9784
# Epoch: 8 | train_loss: 0.1993 | train_acc: 0.9271 | test_loss: 0.1141 | test_acc: 0.9722
# Epoch: 9 | train_loss: 0.0770 | train_acc: 0.9958 | test_loss: 0.1044 | test_acc: 0.9847
# Epoch: 10 | train_loss: 0.1397 | train_acc: 0.9625 | test_loss: 0.1089 | test_acc: 0.9909
# [INFO] Total training time: 41.742 seconds

# %%
plot_results(results=model_2_results)

# %% [markdown]
# ## 6. Try a different model from [`torchvision.models`](https://pytorch.org/vision/stable/models.html) on the Pizza, Steak, Sushi data, how does this model perform?
# * You'll have to change the size of the classifier layer to suit our problem.
# * You may want to try an EfficientNet with a higher number than our B0, perhaps `torchvision.models.efficientnet_b2()`?
#   * **Note:** Depending on the model you use you will have to prepare/transform the data in a certain way.

# %%
# PREPARE DATA

transforms_b2 = torchvision.models.EfficientNet_B2_Weights.IMAGENET1K_V1.transforms()

# Create training and testing DataLoader's as well as get a list of class names
train_dataloader_b2, test_dataloader_b2, class_names = data_setup.create_dataloaders(
    train_dir=train_dir_20_percent,
    test_dir=test_dir_20_percent,
    transform=transforms_b2,  # resize, convert images to between 0 & 1 and normalize them
    batch_size=32,
)  # set mini-batch size to 32
train_dataloader_b2, test_dataloader_b2, class_names
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x79da2ec6b370>,
#  <torch.utils.data.dataloader.DataLoader at 0x79d898f17e20>,
#  ['pizza', 'steak', 'sushi'])

# %%
transforms_b2
# Out:
# ImageClassification(
#     crop_size=[288]
#     resize_size=[288]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BICUBIC
# )

# %%
# Setup device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
# TODO

weights = torchvision.models.EfficientNet_B2_Weights.IMAGENET1K_V1
model_3 = torchvision.models.efficientnet_b2(weights=weights).to(device)

model_3 = model_3.to(device=device)
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b2_rwightman-c35c1473.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b2_rwightman-c35c1473.pth
# 100%|██████████| 35.2M/35.2M [00:00<00:00, 135MB/s]

# %%
# Set the manual seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Get the length of class_names (one output unit for each class)
output_shape = len(class_names)

# Recreate the classifier layer and seed it to the target device
model_3.classifier = torch.nn.Sequential(
    torch.nn.Dropout(p=0.2, inplace=True),
    torch.nn.Linear(
        in_features=1408,
        out_features=output_shape,  # same number of output units as our number of classes
        bias=True,
    ),
).to(device)

# print(model_3)

# %%
summary(
    model_3,
    # make sure this is "input_size", not "input_shape" (batch_size, color_channels, height, width)
    input_size=(1, 3, 288, 288),
    verbose=0,
    col_names=["input_size", "output_size", "num_params", "trainable"],
    col_width=20,
    row_settings=["var_names"],
    device="cpu",
)
# Out:
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# EfficientNet (EfficientNet)                                  [1, 3, 288, 288]     [1, 3]               --                   True
# ├─Sequential (features)                                      [1, 3, 288, 288]     [1, 1408, 9, 9]      --                   True
# │    └─Conv2dNormActivation (0)                              [1, 3, 288, 288]     [1, 32, 144, 144]    --                   True
# │    │    └─Conv2d (0)                                       [1, 3, 288, 288]     [1, 32, 144, 144]    864                  True
# │    │    └─BatchNorm2d (1)                                  [1, 32, 144, 144]    [1, 32, 144, 144]    64                   True
# │    │    └─SiLU (2)                                         [1, 32, 144, 144]    [1, 32, 144, 144]    --                   --
# │    └─Sequential (1)                                        [1, 32, 144, 144]    [1, 16, 144, 144]    --                   True
# │    │    └─MBConv (0)                                       [1, 32, 144, 144]    [1, 16, 144, 144]    1,448                True
# │    │    └─MBConv (1)                                       [1, 16, 144, 144]    [1, 16, 144, 144]    612                  True
# │    └─Sequential (2)                                        [1, 16, 144, 144]    [1, 24, 72, 72]      --                   True
# │    │    └─MBConv (0)                                       [1, 16, 144, 144]    [1, 24, 72, 72]      6,004                True
# │    │    └─MBConv (1)                                       [1, 24, 72, 72]      [1, 24, 72, 72]      10,710               True
# │    │    └─MBConv (2)                                       [1, 24, 72, 72]      [1, 24, 72, 72]      10,710               True
# │    └─Sequential (3)                                        [1, 24, 72, 72]      [1, 48, 36, 36]      --                   True
# │    │    └─MBConv (0)                                       [1, 24, 72, 72]      [1, 48, 36, 36]      16,518               True
# │    │    └─MBConv (1)                                       [1, 48, 36, 36]      [1, 48, 36, 36]      43,308               True
# │    │    └─MBConv (2)                                       [1, 48, 36, 36]      [1, 48, 36, 36]      43,308               True
# │    └─Sequential (4)                                        [1, 48, 36, 36]      [1, 88, 18, 18]      --                   True
# │    │    └─MBConv (0)                                       [1, 48, 36, 36]      [1, 88, 18, 18]      50,300               True
# │    │    └─MBConv (1)                                       [1, 88, 18, 18]      [1, 88, 18, 18]      123,750              True
# │    │    └─MBConv (2)                                       [1, 88, 18, 18]      [1, 88, 18, 18]      123,750              True
# │    │    └─MBConv (3)                                       [1, 88, 18, 18]      [1, 88, 18, 18]      123,750              True
# │    └─Sequential (5)                                        [1, 88, 18, 18]      [1, 120, 18, 18]     --                   True
# │    │    └─MBConv (0)                                       [1, 88, 18, 18]      [1, 120, 18, 18]     149,158              True
# │    │    └─MBConv (1)                                       [1, 120, 18, 18]     [1, 120, 18, 18]     237,870              True
# │    │    └─MBConv (2)                                       [1, 120, 18, 18]     [1, 120, 18, 18]     237,870              True
# │    │    └─MBConv (3)                                       [1, 120, 18, 18]     [1, 120, 18, 18]     237,870              True
# │    └─Sequential (6)                                        [1, 120, 18, 18]     [1, 208, 9, 9]       --                   True
# │    │    └─MBConv (0)                                       [1, 120, 18, 18]     [1, 208, 9, 9]       301,406              True
# │    │    └─MBConv (1)                                       [1, 208, 9, 9]       [1, 208, 9, 9]       686,868              True
# │    │    └─MBConv (2)                                       [1, 208, 9, 9]       [1, 208, 9, 9]       686,868              True
# │    │    └─MBConv (3)                                       [1, 208, 9, 9]       [1, 208, 9, 9]       686,868              True
# │    │    └─MBConv (4)                                       [1, 208, 9, 9]       [1, 208, 9, 9]       686,868              True
# │    └─Sequential (7)                                        [1, 208, 9, 9]       [1, 352, 9, 9]       --                   True
# │    │    └─MBConv (0)                                       [1, 208, 9, 9]       [1, 352, 9, 9]       846,900              True
# │    │    └─MBConv (1)                                       [1, 352, 9, 9]       [1, 352, 9, 9]       1,888,920            True
# │    └─Conv2dNormActivation (8)                              [1, 352, 9, 9]       [1, 1408, 9, 9]      --                   True
# │    │    └─Conv2d (0)                                       [1, 352, 9, 9]       [1, 1408, 9, 9]      495,616              True
# │    │    └─BatchNorm2d (1)                                  [1, 1408, 9, 9]      [1, 1408, 9, 9]      2,816                True
# │    │    └─SiLU (2)                                         [1, 1408, 9, 9]      [1, 1408, 9, 9]      --                   --
# ├─AdaptiveAvgPool2d (avgpool)                                [1, 1408, 9, 9]      [1, 1408, 1, 1]      --                   --
# ├─Sequential (classifier)                                    [1, 1408]            [1, 3]               --                   True
# │    └─Dropout (0)                                           [1, 1408]            [1, 1408]            --                   --
# │    └─Linear (1)                                            [1, 1408]            [1, 3]               4,227                True
# ============================================================================================================================================
# Total params: 7,705,221
# Trainable params: 7,705,221
# Non-trainable params: 0
# Total mult-adds (G): 1.09
# ============================================================================================================================================
# Input size (MB): 1.00
# Forward/backward pass size (MB): 259.12
# Params size (MB): 30.82
# Estimated Total Size (MB): 290.93
# ============================================================================================================================================

# %%
# TODO

# Set the random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Start the timer
from timeit import default_timer as timer

start_time = timer()

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_3.parameters(), lr=0.001)

# Setup training and save the results
model_3_results = engine.train(
    model=model_3,
    train_dataloader=train_dataloader_b2,
    test_dataloader=test_dataloader_b2,
    optimizer=optimizer,
    loss_fn=loss_fn,
    epochs=20,
    device=device,
)

# End the timer and print out how long it took
end_time = timer()
print(f"[INFO] Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 0.1421 | train_acc: 0.9667 | test_loss: 0.4133 | test_acc: 0.8761
# Epoch: 2 | train_loss: 0.1823 | train_acc: 0.9375 | test_loss: 0.2293 | test_acc: 0.9347
# Epoch: 3 | train_loss: 0.2199 | train_acc: 0.9313 | test_loss: 0.1702 | test_acc: 0.9534
# Epoch: 4 | train_loss: 0.0774 | train_acc: 0.9812 | test_loss: 0.4765 | test_acc: 0.8938
# Epoch: 5 | train_loss: 0.1251 | train_acc: 0.9625 | test_loss: 0.0813 | test_acc: 0.9602
# Epoch: 6 | train_loss: 0.4554 | train_acc: 0.9146 | test_loss: 0.1508 | test_acc: 0.9472
# Epoch: 7 | train_loss: 0.2387 | train_acc: 0.9375 | test_loss: 0.1395 | test_acc: 0.9477
# Epoch: 8 | train_loss: 0.4421 | train_acc: 0.9104 | test_loss: 1.5866 | test_acc: 0.6886
# Epoch: 9 | train_loss: 0.2500 | train_acc: 0.9125 | test_loss: 0.2534 | test_acc: 0.9290
# Epoch: 10 | train_loss: 0.3786 | train_acc: 0.9083 | test_loss: 0.1150 | test_acc: 0.9597
# Epoch: 11 | train_loss: 0.1597 | train_acc: 0.9333 | test_loss: 0.1337 | test_acc: 0.9568
# Epoch: 12 | train_loss: 0.1147 | train_acc: 0.9646 | test_loss: 0.1307 | test_acc: 0.9381
# Epoch: 13 | train_loss: 0.0505 | train_acc: 0.9854 | test_loss: 0.0981 | test_acc: 0.9659
# Epoch: 14 | train_loss: 0.0216 | train_acc: 0.9938 | test_loss: 0.0575 | test_acc: 0.9812
# Epoch: 15 | train_loss: 0.0553 | train_acc: 0.9938 | test_loss: 0.0789 | test_acc: 0.9722
# Epoch: 16 | train_loss: 0.2612 | train_acc: 0.9542 | test_loss: 0.0767 | test_acc: 0.9812
# Epoch: 17 | train_loss: 0.0980 | train_acc: 0.9646 | test_loss: 0.3058 | test_acc: 0.8949
# Epoch: 18 | train_loss: 0.0822 | train_acc: 0.9896 | test_loss: 0.1483 | test_acc: 0.9534
# Epoch: 19 | train_loss: 0.0370 | train_acc: 0.9896 | test_loss: 0.2101 | test_acc: 0.9472
# Epoch: 20 | train_loss: 0.1429 | train_acc: 0.9625 | test_loss: 0.1640 | test_acc: 0.9568
# [INFO] Total training time: 153.334 seconds

# %%
plot_results(results=model_3_results)

# %% [markdown]
# # Grad_Zero

# %%
# TODO: Recreate a new model
weights = torchvision.models.EfficientNet_B0_Weights.DEFAULT
model_1 = torchvision.models.efficientnet_b0(weights=weights).to(device)

# Set the manual seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

for p in model_1.features.parameters():
    p.requires_grad = False


# Get the length of class_names (one output unit for each class)
output_shape = len(class_names)

# Recreate the classifier layer and seed it to the target device
model_1.classifier = torch.nn.Sequential(
    torch.nn.Dropout(p=0.2, inplace=True),
    torch.nn.Linear(
        in_features=1280,
        out_features=output_shape,  # same number of output units as our number of classes
        bias=True,
    ),
).to(device)


print(
    summary(
        model_1,
        input_size=(
            32,
            3,
            224,
            224,
        ),  # make sure this is "input_size", not "input_shape" (batch_size, color_channels, height, width)
        verbose=0,
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"],
    )
)

# Set the random seeds
from timeit import default_timer as timer

torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Start the timer
start_time = timer()

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_1.parameters(), lr=0.001)


# Setup training and save the results
model_1_results = engine.train(
    model=model_1,
    train_dataloader=train_dataloader,
    test_dataloader=test_dataloader,
    optimizer=optimizer,
    loss_fn=loss_fn,
    epochs=10,
    device=device,
)

# End the timer and print out how long it took
end_time = timer()
print(f"[INFO] Total training time: {end_time-start_time:.3f} seconds")
# Out:
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# EfficientNet (EfficientNet)                                  [32, 3, 224, 224]    [32, 3]              --                   Partial
# ├─Sequential (features)                                      [32, 3, 224, 224]    [32, 1280, 7, 7]     --                   False
# │    └─Conv2dNormActivation (0)                              [32, 3, 224, 224]    [32, 32, 112, 112]   --                   False
# │    │    └─Conv2d (0)                                       [32, 3, 224, 224]    [32, 32, 112, 112]   (864)                False
# │    │    └─BatchNorm2d (1)                                  [32, 32, 112, 112]   [32, 32, 112, 112]   (64)                 False
# │    │    └─SiLU (2)                                         [32, 32, 112, 112]   [32, 32, 112, 112]   --                   --
# │    └─Sequential (1)                                        [32, 32, 112, 112]   [32, 16, 112, 112]   --                   False
# │    │    └─MBConv (0)                                       [32, 32, 112, 112]   [32, 16, 112, 112]   (1,448)              False
# │    └─Sequential (2)                                        [32, 16, 112, 112]   [32, 24, 56, 56]     --                   False
# │    │    └─MBConv (0)                                       [32, 16, 112, 112]   [32, 24, 56, 56]     (6,004)              False
# │    │    └─MBConv (1)                                       [32, 24, 56, 56]     [32, 24, 56, 56]     (10,710)             False
# │    └─Sequential (3)                                        [32, 24, 56, 56]     [32, 40, 28, 28]     --                   False
# │    │    └─MBConv (0)                                       [32, 24, 56, 56]     [32, 40, 28, 28]     (15,350)             False
# │    │    └─MBConv (1)                                       [32, 40, 28, 28]     [32, 40, 28, 28]     (31,290)             False
# │    └─Sequential (4)                                        [32, 40, 28, 28]     [32, 80, 14, 14]     --                   False
# │    │    └─MBConv (0)                                       [32, 40, 28, 28]     [32, 80, 14, 14]     (37,130)             False
# │    │    └─MBConv (1)                                       [32, 80, 14, 14]     [32, 80, 14, 14]     (102,900)            False
# │    │    └─MBConv (2)                                       [32, 80, 14, 14]     [32, 80, 14, 14]     (102,900)            False
# │    └─Sequential (5)                                        [32, 80, 14, 14]     [32, 112, 14, 14]    --                   False
# │    │    └─MBConv (0)                                       [32, 80, 14, 14]     [32, 112, 14, 14]    (126,004)            False
# │    │    └─MBConv (1)                                       [32, 112, 14, 14]    [32, 112, 14, 14]    (208,572)            False
# │    │    └─MBConv (2)                                       [32, 112, 14, 14]    [32, 112, 14, 14]    (208,572)            False
# │    └─Sequential (6)                                        [32, 112, 14, 14]    [32, 192, 7, 7]      --                   False
# │    │    └─MBConv (0)                                       [32, 112, 14, 14]    [32, 192, 7, 7]      (262,492)            False
# │    │    └─MBConv (1)                                       [32, 192, 7, 7]      [32, 192, 7, 7]      (587,952)            False
# │    │    └─MBConv (2)                                       [32, 192, 7, 7]      [32, 192, 7, 7]      (587,952)            False
# │    │    └─MBConv (3)                                       [32, 192, 7, 7]      [32, 192, 7, 7]      (587,952)            False
# │    └─Sequential (7)                                        [32, 192, 7, 7]      [32, 320, 7, 7]      --                   False
# │    │    └─MBConv (0)                                       [32, 192, 7, 7]      [32, 320, 7, 7]      (717,232)            False
# │    └─Conv2dNormActivation (8)                              [32, 320, 7, 7]      [32, 1280, 7, 7]     --                   False
# │    │    └─Conv2d (0)                                       [32, 320, 7, 7]      [32, 1280, 7, 7]     (409,600)            False
# │    │    └─BatchNorm2d (1)                                  [32, 1280, 7, 7]     [32, 1280, 7, 7]     (2,560)              False
# │    │    └─SiLU (2)                                         [32, 1280, 7, 7]     [32, 1280, 7, 7]     --                   --
# ├─AdaptiveAvgPool2d (avgpool)                                [32, 1280, 7, 7]     [32, 1280, 1, 1]     --                   --
# ├─Sequential (classifier)                                    [32, 1280]           [32, 3]              --                   True
# │    └─Dropout (0)                                           [32, 1280]           [32, 1280]           --                   --
# │    └─Linear (1)                                            [32, 1280]           [32, 3]              3,843                True
# ============================================================================================================================================
# Total params: 4,011,391
# Trainable params: 3,843
# Non-trainable params: 4,007,548
# Total mult-adds (G): 12.31
# ============================================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 3452.09
# Params size (MB): 16.05
# Estimated Total Size (MB): 3487.41
# ============================================================================================================================================
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.0895 | train_acc: 0.4414 | test_loss: 0.9202 | test_acc: 0.5085
# Epoch: 2 | train_loss: 0.8682 | train_acc: 0.7734 | test_loss: 0.8022 | test_acc: 0.7434
# Epoch: 3 | train_loss: 0.7771 | train_acc: 0.7812 | test_loss: 0.7399 | test_acc: 0.7737
# Epoch: 4 | train_loss: 0.7249 | train_acc: 0.7422 | test_loss: 0.6472 | test_acc: 0.8864
# Epoch: 5 | train_loss: 0.6445 | train_acc: 0.7812 | test_loss: 0.6244 | test_acc: 0.8968
# Epoch: 6 | train_loss: 0.6022 | train_acc: 0.7656 | test_loss: 0.5565 | test_acc: 0.8864
# Epoch: 7 | train_loss: 0.5411 | train_acc: 0.9258 | test_loss: 0.5279 | test_acc: 0.9176
# Epoch: 8 | train_loss: 0.5493 | train_acc: 0.8086 | test_loss: 0.5291 | test_acc: 0.9176
# Epoch: 9 | train_loss: 0.5725 | train_acc: 0.7969 | test_loss: 0.4947 | test_acc: 0.9072
# Epoch: 10 | train_loss: 0.5219 | train_acc: 0.7969 | test_loss: 0.4207 | test_acc: 0.8655
# [INFO] Total training time: 19.182 seconds

# %%
plot_results(results=model_1_results)
